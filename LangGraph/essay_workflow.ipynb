# %%
from langgraph.graph import StateGraph,START,END
from langchain_google_genai import ChatGoogleGenerativeAI
from typing import TypedDict, Annotated
from pydantic import BaseModel, Field
import operator
# Out:
# D:\LangChain\.venv\Lib\site-packages\langchain_core\_api\deprecation.py:26: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1

# %%
llm = ChatGoogleGenerativeAI(model="gemini-3-flash-preview",temperature=0)
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.

# %%
class EvaluationSchema(BaseModel):
    feedback:str = Field(description="Detailed feedback for the essay")
    score:int = Field(description="Score out 10",ge=0,le=10)

# %%
structured_llm = llm.with_structured_output(EvaluationSchema)

# %%
class EssayState(TypedDict):
    essay:str
    language_feedback:str
    analysis_feedback:str
    clarity_feedback:str
    overall_feedback:str
    individual_scores:Annotated[list[int],operator.add]
    avg_score:float

# %%
def evaluate_language(state:EssayState):
    prompt = f'Evaluate the language quality of the essay and provide a feedback out of 10. \n: {state["essay"]}'
    output = structured_llm.invoke(prompt)
    return {'language_feedback':output.feedback,'individual_scores':state['individual_scores']+[output.score]}

# %%
def evaluate_analysis(state:EssayState):
    prompt = f'Evaluate the depth of analysis of the essay and provide a feedback out of 10. \n: {state["essay"]}'
    output = structured_llm.invoke(prompt)
    return {'analysis_feedback':output.feedback,'individual_scores':state['individual_scores']+[output.score]}

# %%
def evaluate_thought(state:EssayState):
    prompt = f'Evaluate the clarity of thought of the essay and provide a feedback out of 10. \n: {state["essay"]}'
    output = structured_llm.invoke(prompt)
    return {'clarity_feedback':output.feedback,'individual_scores':state['individual_scores']+[output.score]}

# %%
def final_evaluation(state:EssayState):
    prompt = f"Create an overall feedback for the essay based on the following feedback: \n {state['language_feedback']}, {state['analysis_feedback']}, {state['clarity_feedback']}"
    overall_feedback = llm.invoke(prompt).content
    avg = sum(state['individual_scores'])/len(state['individual_scores'])
    return {'overall_feedback':overall_feedback,'avg_score':avg}

# %%
graph = StateGraph(EssayState)

graph.add_node('evaluate_language',evaluate_language)
graph.add_node('evaluate_analysis',evaluate_analysis)
graph.add_node('evaluate_thought',evaluate_thought)
graph.add_node('final_evaluation',final_evaluation)

#add edges
graph.add_edge(START,'evaluate_language')
graph.add_edge(START,'evaluate_analysis')
graph.add_edge(START,'evaluate_thought')

graph.add_edge('evaluate_language','final_evaluation')
graph.add_edge('evaluate_analysis','final_evaluation')
graph.add_edge('evaluate_thought','final_evaluation')

graph.add_edge('final_evaluation',END)

workflow = graph.compile()

# %%
essay = "This is a sample essay."

# %%
initial_state = {'essay':essay}
final_state = workflow.invoke(initial_state)
print(final_state)
# Out:
# {'essay': 'This is a sample essay.', 'language_feedback': 'The text provided is a single, simple sentence rather than a complete essay. It lacks depth, structural complexity, and the necessary components to evaluate language proficiency such as vocabulary range, grammatical variety, or coherence. As it does not meet the requirements of an essay, it cannot be effectively assessed.', 'analysis_feedback': 'The provided text consists of a single sentence and does not contain any substantive content or analysis. As a result, it is impossible to evaluate the depth of analysis, as no arguments or supporting evidence are presented.', 'clarity_feedback': 'The input provided is a single sentence and does not constitute a complete essay. While the sentence itself is clear in its literal meaning, it lacks the depth, structure, and logical progression necessary to evaluate clarity of thought in an academic or creative context. To improve, provide a full-length essay that includes an introduction, body paragraphs with supporting evidence, and a cohesive conclusion.', 'overall_feedback': [{'type': 'text', 'text': 'Here are a few ways to synthesize that feedback into an overall summary, depending on the tone you want to set:\n\n### Option 1: Formal and Direct (Best for a grading rubric)\n**Overall Feedback:** The submitted text does not meet the minimum requirements for an essay assessment. Because the response consists of only a single sentence, it lacks the necessary structure—including an introduction, body paragraphs, and a conclusion—required to evaluate your writing. There is insufficient evidence to assess your depth of analysis, vocabulary range, or grammatical complexity. To receive a formal evaluation, please submit a complete essay that develops a clear argument supported by evidence and logical progression.\n\n### Option 2: Constructive and Encouraging (Best for student growth)\n**Overall Feedback:** While your sentence is clear in its literal meaning, it does not provide enough content to constitute a complete essay. An effective essay requires a structured framework to explore ideas deeply, specifically through a cohesive introduction, supporting body paragraphs, and a conclusion. At this stage, it is impossible to evaluate your analytical skills or language proficiency. I encourage you to expand on this initial thought by providing supporting evidence and a more complex structural variety in your next draft.\n\n### Option 3: Concise (Best for quick feedback)\n**Overall Feedback:** This submission is too brief to be assessed as an essay. It lacks the structural components (intro, body, conclusion) and the analytical depth necessary to demonstrate your writing and reasoning skills. To improve, please provide a full-length response that utilizes a wider range of vocabulary and presents a structured argument with supporting evidence.\n\n### Key Points Included in the Synthesis:\n*   **Format Issue:** It is a single sentence, not an essay.\n*   **Assessment Gap:** Impossible to judge language proficiency, grammar, or logic.\n*   **Missing Content:** Lack of analysis, evidence, and arguments.\n*   **Structural Needs:** Requires an introduction, body, and conclusion.', 'extras': {'signature': '...'}}], 'individual_scores': [0, 1, 1], 'avg_score': 0.6666666666666666}
